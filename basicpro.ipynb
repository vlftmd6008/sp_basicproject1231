# %%
import pandas as pd 

# 사용자 정의 컬럼 이름 설정
column_names = [
    'RCPT_YR', 'CGG_CD', 'CGG_NM', 'STDG_CD', 'STDG_NM', 
    'LOTNO_SE', 'LOTNO_SE_NM', 'MNO', 'SNO', 'BLDG_NM', 
    'CTRT_DAY', 'THING_AMT', 'ARCH_AREA', 'LAND_AREA', 'FLR', 
    'RGHT_SE', 'RTRCN_DAY', 'ARCH_YR', 'BLDG_USG', 'DCLR_SE', 
    'OPBIZ_RESTAGNT_SGG_NM'
]

# 컬럼별 데이터 타입 설정
dtype_dict = {
    'RCPT_YR': 'int64',
    'CGG_CD': 'string',
    'CGG_NM': 'string',
    'STDG_CD': 'string',
    'STDG_NM': 'string',
    'LOTNO_SE': 'string',
    'LOTNO_SE_NM': 'string',
    'MNO': 'string',
    'SNO': 'string',
    'BLDG_NM': 'string',
    'CTRT_DAY': 'string',
    'THING_AMT': 'int64',
    'ARCH_AREA': 'float64',
    'LAND_AREA': 'float64',
    'FLR': 'string', 
    'RGHT_SE': 'string',
    'RTRCN_DAY': 'string', 
    'ARCH_YR': 'string', 
    'BLDG_USG': 'string',
    'DCLR_SE': 'string',
    'OPBIZ_RESTAGNT_SGG_NM': 'string'
}

# 사용자 정의 컬럼 이름과 데이터 타입을 사용하여 CSV 파일 불러오기
df_2018 = pd.read_csv(
    '2018.csv', 
    encoding='euc-kr',  
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1           
)

df_2019 = pd.read_csv(
    '2019.csv', 
    encoding='euc-kr',   
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1          
)

df_2020 = pd.read_csv(
    '2020.csv', 
    encoding='euc-kr',   
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1          
)

df_2021 = pd.read_csv(
    '2021.csv', 
    encoding='euc-kr',   
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1          
)

df_2022 = pd.read_csv(
    '2022.csv', 
    encoding='euc-kr',   
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1          
)

df_2023 = pd.read_csv(
    '2023.csv', 
    encoding='euc-kr',   
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1          
)

df_2024 = pd.read_csv(
    '2024.csv', 
    encoding='euc-kr',   
    names=column_names,  
    dtype=dtype_dict,   
    skiprows=1          
)

# %%
# 연도별, 건물용도별 가격 평균, 변동률
mean_df = pd.DataFrame()
df_dict = {2018: df_2018,
           2019: df_2019,
           2020: df_2020,
           2021: df_2021,
           2022: df_2022,
           2023: df_2023,
           2024: df_2024}
for year, df in df_dict.items():
    mean_df[f'{year} 평균금액'] = df.groupby('BLDG_USG')['THING_AMT'].mean()
for year in range(2019, 2025):
    mean_df[f'{year} 변동률(%)'] = ((mean_df[f'{year} 평균금액'] - mean_df[f'{year-1} 평균금액']) / mean_df[f'{year-1} 평균금액']) * 100
mean_df
# Out:
#              2018 평균금액      2019 평균금액      2020 평균금액      2021 평균금액  \
# BLDG_USG
# 단독다가구     96121.568660  105862.942609  120827.123004  153328.529057
# 아파트       67012.218342   82119.987685   83997.721610  103106.891175
# 연립다세대     26904.981040   27439.993125   29063.854651   30397.312585
# 오피스텔      25110.580697   25140.112130   27457.737542   27432.872446
#
#               2022 평균금액      2023 평균금액      2024 평균금액  2019 변동률(%)  \
# BLDG_USG
# 단독다가구     201517.304908  181304.837877  166188.087568    10.134431
# 아파트        98737.506523  107180.009430  118386.256697    22.544798
# 연립다세대      33073.464666   35574.331260   35977.487207     1.988524
# 오피스텔       25847.609370   26975.646399   29947.522440     0.117606
#
#           2020 변동률(%)  2021 변동률(%)  2022 변동률(%)  2023 변동률(%)  2024 변동률(%)
# BLDG_USG
# 단독다가구       14.135428    26.899098    31.428447   -10.030140    -8.337753
# 아파트          2.286574    22.749628    -4.237723     8.550452    10.455539
# 연립다세대        5.917864     4.588028     8.803910     7.561550     1.133278
# 오피스텔         9.218835    -0.090558    -5.778699     4.364183    11.016885

# %%
# import matplotlib.pyplot as plt
# import matplotlib.font_manager as fm
# import matplotlib as mpl
# # 폰트 경로 지정 (NanumGothic 폰트 파일 위치)
# font_path = 'NanumGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path)
# # matplotlib 기본 폰트로 설정
# plt.rcParams['font.family'] = fontprop.get_name()
# plt.rcParams['axes.unicode_minus'] = False
# 연도 = [i for i in range(2018, 2025)]
# mean_df = mean_df.reset_index()
# 단독다가구 = mean_df[mean_df['BLDG_USG'] == '단독다가구'].loc[:, '2018 평균금액':'2024 평균금액'].iloc[0]
# 아파트 = mean_df[mean_df['BLDG_USG'] == '아파트'].loc[:, '2018 평균금액':'2024 평균금액'].iloc[0]
# 연립다세대 = mean_df[mean_df['BLDG_USG'] == '연립다세대'].loc[:, '2018 평균금액':'2024 평균금액'].iloc[0]
# 오피스텔 = mean_df[mean_df['BLDG_USG'] == '오피스텔'].loc[:, '2018 평균금액':'2024 평균금액'].iloc[0]
# plt.plot(연도, 단독다가구, 'ro-', label='단독다가구')
# plt.plot(연도, 아파트, 'bo-', label='아파트')
# plt.plot(연도, 연립다세대, 'go-', label='연립다세대')
# plt.plot(연도, 오피스텔, 'co-', label='오피스텔')
# plt.xlabel('YEAR', labelpad=15)
# plt.ylabel('AVG_THING_AMT', labelpad=15)
# plt.legend(prop=fontprop)
# plt.title('평균금액 추이', fontproperties=fontprop)
# plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %%
# 연도 = [i for i in range(2019, 2025)]
# 단독다가구_변동률 = mean_df[mean_df['BLDG_USG'] == '단독다가구'].loc[:, '2019 변동률(%)':'2024 변동률(%)'].iloc[0]
# 아파트_변동률 = mean_df[mean_df['BLDG_USG'] == '아파트'].loc[:, '2019 변동률(%)':'2024 변동률(%)'].iloc[0]
# 연립다세대_변동률 = mean_df[mean_df['BLDG_USG'] == '연립다세대'].loc[:, '2019 변동률(%)':'2024 변동률(%)'].iloc[0]
# 오피스텔_변동률 = mean_df[mean_df['BLDG_USG'] == '오피스텔'].loc[:, '2019 변동률(%)':'2024 변동률(%)'].iloc[0]
# plt.plot(연도, 단독다가구_변동률, 'r-', label='단독다가구 변동률')
# plt.plot(연도, 아파트_변동률, 'b-', label='아파트 변동률')
# plt.plot(연도, 연립다세대_변동률, 'g-', label='연립다세대 변동률')
# plt.plot(연도, 오피스텔_변동률, 'c-', label='오피스텔 변동률')
# plt.xlabel('YEAR', labelpad=15)
# plt.ylabel('BLDG_USG', labelpad=15)
# plt.legend(prop=fontprop)
# plt.title('가격 변동률 추이', fontproperties=fontprop)
# plt.hlines(0, 2019, 2024, color='gray', linestyle='--', linewidth=1)
# plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %%
# 해당년도 가격에 가격변동률을 곱해서 조정가격 구하기
for i in range(2018, 2024):
    df_dict[i]['THING_AMT'] = df_dict[i].apply(
        lambda x: (
            x['THING_AMT'] * (1 + mean_df.loc['단독다가구', f'{i+1} 변동률(%)'] / 100) if x['BLDG_USG'] == '단독다가구' else
            x['THING_AMT'] * (1 + mean_df.loc['아파트', f'{i+1} 변동률(%)'] / 100) if x['BLDG_USG'] == '아파트' else
            x['THING_AMT'] * (1 + mean_df.loc['연립다세대', f'{i+1} 변동률(%)'] / 100) if x['BLDG_USG'] == '연립다세대' else
            x['THING_AMT'] * (1 + mean_df.loc['오피스텔', f'{i+1} 변동률(%)'] / 100) if x['BLDG_USG'] == '오피스텔' else
            None
        ),
        axis = 1
    )
    df_dict[i+1] = pd.concat([df_dict[i+1], df_dict[i]], axis=0, ignore_index=True)
# 최종적으로 사용할 데이터프레임
real_estate = df_dict[2024]
real_estate.head()
# Out:
#    RCPT_YR CGG_CD CGG_NM STDG_CD STDG_NM LOTNO_SE LOTNO_SE_NM   MNO   SNO  \
# 0     2024  11380    은평구   10200     녹번동        1          대지  0086  0125
# 1     2024  11500    강서구   10300     화곡동        1          대지  0924  0004
# 2     2024  11560   영등포구   11100   당산동1가        1          대지  0143  0000
# 3     2024  11560   영등포구   12800   양평동4가        1          대지  0220  0000
# 4     2024  11410   서대문구   11200     대현동        1          대지  0090  0077
#
#         BLDG_NM  ... THING_AMT  ARCH_AREA  LAND_AREA  FLR RGHT_SE RTRCN_DAY  \
# 0  성원빌라(86-125)  ...   16400.0      53.07    25.0000    4    <NA>      <NA>
# 1          팔팔빌라  ...   35000.0      39.24    27.0000    2    <NA>      <NA>
# 2        다솔시티하임  ...   30000.0      29.54    14.0000    5    <NA>      <NA>
# 3           해울빌  ...   36000.0      40.41    63.6400    3    <NA>      <NA>
# 4        유씨유 이대  ...   19300.0      17.31    30.8725    5    <NA>      <NA>
#
#   ARCH_YR BLDG_USG DCLR_SE OPBIZ_RESTAGNT_SGG_NM
# 0    1991    연립다세대    중개거래                서울 은평구
# 1    1986    연립다세대     직거래                  <NA>
# 2    2017    연립다세대     직거래                  <NA>
# 3    2021     오피스텔    중개거래                서울 용산구
# 4    2018     오피스텔    중개거래               서울 서대문구
#
# [5 rows x 21 columns]

# %%
# 공공데이터 매물 주소 구하기
real_estate['MNO'] = real_estate['MNO'].str.lstrip('0')
real_estate['SNO'] = real_estate['SNO'].str.lstrip('0')

def address(x):
    if pd.notna(x['MNO']) and x['MNO'] != '':
        if pd.notna(x['SNO']) and x['SNO'] != '':
            return '서울특별시' + ' ' + x['CGG_NM'] + ' ' + x['STDG_NM'] + ' ' + x['MNO'] + '-' + x['SNO']
        else:
            return '서울특별시' + ' ' + x['CGG_NM'] + ' ' + x['STDG_NM'] + ' ' + x['MNO']
    else:
        return '서울특별시' + ' ' + x['CGG_NM'] + ' ' + x['STDG_NM']

real_estate['address'] = real_estate.apply(address, axis=1)

# %%
# 취소일이 지정된 매물 제외하기
real_estate = real_estate[real_estate['RTRCN_DAY'].isnull()]
real_estate.head(3)
# Out:
#    RCPT_YR CGG_CD CGG_NM STDG_CD STDG_NM LOTNO_SE LOTNO_SE_NM  MNO  SNO  \
# 0     2024  11380    은평구   10200     녹번동        1          대지   86  125
# 1     2024  11500    강서구   10300     화곡동        1          대지  924    4
# 2     2024  11560   영등포구   11100   당산동1가        1          대지  143
#
#         BLDG_NM  ... ARCH_AREA  LAND_AREA  FLR  RGHT_SE RTRCN_DAY ARCH_YR  \
# 0  성원빌라(86-125)  ...     53.07       25.0    4     <NA>      <NA>    1991
# 1          팔팔빌라  ...     39.24       27.0    2     <NA>      <NA>    1986
# 2        다솔시티하임  ...     29.54       14.0    5     <NA>      <NA>    2017
#
#   BLDG_USG DCLR_SE OPBIZ_RESTAGNT_SGG_NM               address
# 0    연립다세대    중개거래                서울 은평구  서울특별시 은평구 녹번동 86-125
# 1    연립다세대     직거래                  <NA>   서울특별시 강서구 화곡동 924-4
# 2    연립다세대     직거래                  <NA>  서울특별시 영등포구 당산동1가 143
#
# [3 rows x 22 columns]

# %%
## 방개수와 신축여부 구하기
real_estate = real_estate[['CGG_NM','STDG_NM','MNO','SNO','BLDG_NM','ARCH_AREA','ARCH_YR','THING_AMT','FLR','BLDG_USG','address']]
def count_room(x):
  if x<=30:
    return '1개'
  elif x<=70:
    return '2개'
  elif x<=100:
    return '3개'
  else :
    return '4개'

real_estate['방개수']=real_estate.apply(lambda x:count_room(x['ARCH_AREA']), axis=1)
real_estate.head()

def standard(x):
  list_i=[]
  for i in range(2019, 2025):
    i = str(i)
    list_i.append(i)
  if str(x) in (list_i):
    return '신축'
  else :
    return '구축'

real_estate['신축여부']=real_estate.apply(lambda x:standard(x['ARCH_YR']), axis=1)
real_estate
# Out:
#        CGG_NM STDG_NM  MNO  SNO       BLDG_NM  ARCH_AREA ARCH_YR  \
# 0         은평구     녹번동   86  125  성원빌라(86-125)      53.07    1991
# 1         강서구     화곡동  924    4          팔팔빌라      39.24    1986
# 2        영등포구   당산동1가  143             다솔시티하임      29.54    2017
# 3        영등포구   양평동4가  220                해울빌      40.41    2021
# 4        서대문구     대현동   90   77        유씨유 이대      17.31    2018
# ...       ...     ...  ...  ...           ...        ...     ...
# 833609    성동구     행당동  375               두산위브      59.99    2009
# 833610    성동구     행당동  375               두산위브      59.99    2009
# 833611    성동구   하왕십리동  258               청계벽산     114.46    1996
# 833612    은평구     역촌동    3   29         청록아트빌      54.47    2001
# 833613   영등포구    여의도동   54                 진주      94.31    1977
#
#             THING_AMT FLR BLDG_USG               address 방개수 신축여부
# 0        16400.000000   4    연립다세대  서울특별시 은평구 녹번동 86-125  2개   구축
# 1        35000.000000   2    연립다세대   서울특별시 강서구 화곡동 924-4  2개   구축
# 2        30000.000000   5    연립다세대  서울특별시 영등포구 당산동1가 143  1개   구축
# 3        36000.000000   3     오피스텔  서울특별시 영등포구 양평동4가 220  2개   신축
# 4        19300.000000   5     오피스텔  서울특별시 서대문구 대현동 90-77  1개   구축
# ...               ...  ..      ...                   ...  ..  ...
# 833609   82148.615172   4      아파트     서울특별시 성동구 행당동 375  2개   구축
# 833610   82148.615172   3      아파트     서울특별시 성동구 행당동 375  2개   구축
# 833611   84798.570500  18      아파트   서울특별시 성동구 하왕십리동 258  4개   구축
# 833612   24069.698053   1    연립다세대    서울특별시 은평구 역촌동 3-29  2개   구축
# 833613  125431.218865   7      아파트    서울특별시 영등포구 여의도동 54  3개   구축
#
# [808073 rows x 13 columns]

# %%
# 1. 고객이 원하는 기준으로 가격, 방 개수, 건물종류, 신축여부로 필터링하기

from IPython.display import display
def filter_by_price(df):
    try:
        y = int(input('금액을 입력해주세요: '))
        filtered = df[df['THING_AMT'] < y]
        return filtered
    except ValueError:
        print("금액은 숫자로 입력해주세요.")
        return df  # 필터링 없이 원본 반환
def filter_by_rooms(df):
    rooms = input('\n방 개수를 입력해주세요: ').strip()
    filtered = df[df['방개수'] == rooms]  # 숫자형이면 int(rooms)
    return filtered
def filter_by_usg(df):
  usg = input('\n건물종류를 입력해주세요: ').strip()
  filtered = df[df['BLDG_USG'] == usg]
  return filtered
def filter_by_new_old(df):
  new_old= input('\n신축,구축 여부를 입력해주세요: ').strip()
  filtered = df[df['신축여부'] == new_old]
  return filtered
df_price = filter_by_price(real_estate)
print("\n[금액 조건으로 필터링된 결과]")
display(df_price)
df_rooms = filter_by_rooms(df_price)
print("\n[방 개수 조건으로 필터링된 결과]")
display(df_rooms)
df_usg = filter_by_usg(df_rooms)
print("\n[BLDG_USG 조건으로 필터링된 결과]")
display(df_usg)
df_final = filter_by_new_old(df_usg)
print("\n[신축,구축여부 조건으로 필터링된 결과]")
display(df_final)
df_final.reset_index(drop=True, inplace=True)
df_final.index = range(1, len(df_final) + 1)
display(df_final)
# Out:
# [금액 조건으로 필터링된 결과]
#        CGG_NM STDG_NM  MNO  SNO       BLDG_NM  ARCH_AREA ARCH_YR  \
# 0         은평구     녹번동   86  125  성원빌라(86-125)      53.07    1991
# 1         강서구     화곡동  924    4          팔팔빌라      39.24    1986
# 2        영등포구   당산동1가  143             다솔시티하임      29.54    2017
# 3        영등포구   양평동4가  220                해울빌      40.41    2021
# 4        서대문구     대현동   90   77        유씨유 이대      17.31    2018
# ...       ...     ...  ...  ...           ...        ...     ...
# 833594    성북구  동소문동5가   15          성신여대역 솔하임      15.94       0
# 833595    성북구  동소문동5가   15          성신여대역 솔하임      15.94       0
# 833596    성북구  동소문동5가   15          성신여대역 솔하임      15.94       0
# 833597    성북구  동소문동5가   15          성신여대역 솔하임      15.94       0
# 833612    은평구     역촌동    3   29         청록아트빌      54.47    2001
#
#            THING_AMT FLR BLDG_USG               address 방개수 신축여부
# 0       16400.000000   4    연립다세대  서울특별시 은평구 녹번동 86-125  2개   구축
# 1       35000.000000   2    연립다세대   서울특별시 강서구 화곡동 924-4  2개   구축
# 2       30000.000000   5    연립다세대  서울특별시 영등포구 당산동1가 143  1개   구축
# 3       36000.000000   3     오피스텔  서울특별시 영등포구 양평동4가 220  2개   신축
# 4       19300.000000   5     오피스텔  서울특별시 서대문구 대현동 90-77  1개   구축
# ...              ...  ..      ...                   ...  ..  ...
# 833594  38689.347791  15      아파트   서울특별시 성북구 동소문동5가 15  1개   구축
# 833595  38689.347791  15      아파트   서울특별시 성북구 동소문동5가 15  1개   구축
# 833596  38689.347791  16      아파트   서울특별시 성북구 동소문동5가 15  1개   구축
# 833597  38689.347791  16      아파트   서울특별시 성북구 동소문동5가 15  1개   구축
# 833612  24069.698053   1    연립다세대    서울특별시 은평구 역촌동 3-29  2개   구축
#
# [309190 rows x 13 columns]
# [방 개수 조건으로 필터링된 결과]
#        CGG_NM STDG_NM  MNO  SNO       BLDG_NM  ARCH_AREA ARCH_YR  \
# 21        구로구     구로동  317   31  호정빌라(317-31)     70.160    1997
# 110       강서구     등촌동  526   25        뜨레비앙2차     78.675    2007
# 130       관악구     봉천동  656    9        그린아이티빌     78.290    2002
# 134       강동구     성내동  454   12         남광하이빌     72.100    2004
# 267      동대문구     장안동  385    2            리치     75.480    2008
# ...       ...     ...  ...  ...           ...        ...     ...
# 832002    강서구     화곡동  410  145         홈피아맨션     74.980    1994
# 832249    마포구     성산동  606    6         혜원빌리지     76.740    1993
# 832505    은평구     불광동  221    7          삼성빌라     70.670    2001
# 833105    양천구      목동  642    8    현대파크빌(642)     82.200    2003
# 833193   서대문구     홍은동  394    8  상하빌리지(394-8)     77.070    2008
#
#            THING_AMT FLR BLDG_USG                address 방개수 신축여부
# 21      31500.000000   3    연립다세대   서울특별시 구로구 구로동 317-31  3개   구축
# 110     37500.000000   3    연립다세대   서울특별시 강서구 등촌동 526-25  3개   구축
# 130     32000.000000   1    연립다세대    서울특별시 관악구 봉천동 656-9  3개   구축
# 134     32500.000000   4    연립다세대   서울특별시 강동구 성내동 454-12  3개   구축
# 267     28100.000000   3      아파트   서울특별시 동대문구 장안동 385-2  3개   구축
# ...              ...  ..      ...                    ...  ..  ...
# 832002  25139.462410   1    연립다세대  서울특별시 강서구 화곡동 410-145  3개   구축
# 832249  39180.119608   1    연립다세대    서울특별시 마포구 성산동 606-6  3개   구축
# 832505  34499.900542   3    연립다세대    서울특별시 은평구 불광동 221-7  3개   구축
# 833105  39781.862059   3    연립다세대     서울특별시 양천구 목동 642-8  3개   구축
# 833193  32627.812916   4    연립다세대   서울특별시 서대문구 홍은동 394-8  3개   구축
#
# [10536 rows x 13 columns]
# [BLDG_USG 조건으로 필터링된 결과]
#        CGG_NM STDG_NM  MNO  SNO      BLDG_NM  ARCH_AREA ARCH_YR     THING_AMT  \
# 267      동대문구     장안동  385    2           리치      75.48    2008  28100.000000
# 320       성북구     정릉동  266   32        대창쉐르빌      72.99    2000  35500.000000
# 1272     서대문구     홍제동  322   79           경일      73.08    2004  35000.000000
# 3830      강서구     화곡동  161    7       대호스카이빌      75.04    2001  29600.000000
# 4973      노원구     중계동   68    1         한신월드      84.38    2005  27100.000000
# ...       ...     ...  ...  ...          ...        ...     ...           ...
# 822120   서대문구     홍제동  104   20         안산맨숀      76.03    1972  31799.463938
# 822931    구로구     고척동  227    1           한성      70.20    1986  39042.675168
# 824495    강서구     화곡동  935    9          무궁화      72.98    1992  36216.056151
# 824628    은평구     갈현동  281  236  인우(281-236)      76.65    1999  36216.056151
# 830190    양천구     신월동  530    7           우창      82.61    2003  35332.737709
#
#        FLR BLDG_USG                address 방개수 신축여부
# 267      3      아파트   서울특별시 동대문구 장안동 385-2  3개   구축
# 320      3      아파트   서울특별시 성북구 정릉동 266-32  3개   구축
# 1272     3      아파트  서울특별시 서대문구 홍제동 322-79  3개   구축
# 3830     1      아파트    서울특별시 강서구 화곡동 161-7  3개   구축
# 4973     3      아파트     서울특별시 노원구 중계동 68-1  3개   구축
# ...     ..      ...                    ...  ..  ...
# 822120   5      아파트  서울특별시 서대문구 홍제동 104-20  3개   구축
# 822931   5      아파트    서울특별시 구로구 고척동 227-1  3개   구축
# 824495   8      아파트    서울특별시 강서구 화곡동 935-9  3개   구축
# 824628   1      아파트  서울특별시 은평구 갈현동 281-236  3개   구축
# 830190   6      아파트    서울특별시 양천구 신월동 530-7  3개   구축
#
# [645 rows x 13 columns]
# [신축,구축여부 조건으로 필터링된 결과]
#        CGG_NM STDG_NM  MNO  SNO      BLDG_NM  ARCH_AREA ARCH_YR     THING_AMT  \
# 267      동대문구     장안동  385    2           리치      75.48    2008  28100.000000
# 320       성북구     정릉동  266   32        대창쉐르빌      72.99    2000  35500.000000
# 1272     서대문구     홍제동  322   79           경일      73.08    2004  35000.000000
# 3830      강서구     화곡동  161    7       대호스카이빌      75.04    2001  29600.000000
# 4973      노원구     중계동   68    1         한신월드      84.38    2005  27100.000000
# ...       ...     ...  ...  ...          ...        ...     ...           ...
# 822120   서대문구     홍제동  104   20         안산맨숀      76.03    1972  31799.463938
# 822931    구로구     고척동  227    1           한성      70.20    1986  39042.675168
# 824495    강서구     화곡동  935    9          무궁화      72.98    1992  36216.056151
# 824628    은평구     갈현동  281  236  인우(281-236)      76.65    1999  36216.056151
# 830190    양천구     신월동  530    7           우창      82.61    2003  35332.737709
#
#        FLR BLDG_USG                address 방개수 신축여부
# 267      3      아파트   서울특별시 동대문구 장안동 385-2  3개   구축
# 320      3      아파트   서울특별시 성북구 정릉동 266-32  3개   구축
# 1272     3      아파트  서울특별시 서대문구 홍제동 322-79  3개   구축
# 3830     1      아파트    서울특별시 강서구 화곡동 161-7  3개   구축
# 4973     3      아파트     서울특별시 노원구 중계동 68-1  3개   구축
# ...     ..      ...                    ...  ..  ...
# 822120   5      아파트  서울특별시 서대문구 홍제동 104-20  3개   구축
# 822931   5      아파트    서울특별시 구로구 고척동 227-1  3개   구축
# 824495   8      아파트    서울특별시 강서구 화곡동 935-9  3개   구축
# 824628   1      아파트  서울특별시 은평구 갈현동 281-236  3개   구축
# 830190   6      아파트    서울특별시 양천구 신월동 530-7  3개   구축
#
# [607 rows x 13 columns]
#     CGG_NM STDG_NM  MNO  SNO      BLDG_NM  ARCH_AREA ARCH_YR     THING_AMT  \
# 1     동대문구     장안동  385    2           리치      75.48    2008  28100.000000
# 2      성북구     정릉동  266   32        대창쉐르빌      72.99    2000  35500.000000
# 3     서대문구     홍제동  322   79           경일      73.08    2004  35000.000000
# 4      강서구     화곡동  161    7       대호스카이빌      75.04    2001  29600.000000
# 5      노원구     중계동   68    1         한신월드      84.38    2005  27100.000000
# ..     ...     ...  ...  ...          ...        ...     ...           ...
# 603   서대문구     홍제동  104   20         안산맨숀      76.03    1972  31799.463938
# 604    구로구     고척동  227    1           한성      70.20    1986  39042.675168
# 605    강서구     화곡동  935    9          무궁화      72.98    1992  36216.056151
# 606    은평구     갈현동  281  236  인우(281-236)      76.65    1999  36216.056151
# 607    양천구     신월동  530    7           우창      82.61    2003  35332.737709
#
#     FLR BLDG_USG                address 방개수 신축여부
# 1     3      아파트   서울특별시 동대문구 장안동 385-2  3개   구축
# 2     3      아파트   서울특별시 성북구 정릉동 266-32  3개   구축
# 3     3      아파트  서울특별시 서대문구 홍제동 322-79  3개   구축
# 4     1      아파트    서울특별시 강서구 화곡동 161-7  3개   구축
# 5     3      아파트     서울특별시 노원구 중계동 68-1  3개   구축
# ..   ..      ...                    ...  ..  ...
# 603   5      아파트  서울특별시 서대문구 홍제동 104-20  3개   구축
# 604   5      아파트    서울특별시 구로구 고척동 227-1  3개   구축
# 605   8      아파트    서울특별시 강서구 화곡동 935-9  3개   구축
# 606   1      아파트  서울특별시 은평구 갈현동 281-236  3개   구축
# 607   6      아파트    서울특별시 양천구 신월동 530-7  3개   구축
#
# [607 rows x 13 columns]

# %%
# 2. 추천 법정동 찾기(Top N개 법정동 추출)
## 1번에서 추출된 법정동에 지표별 리스트를 merge → 모든 지표값이 null이면 해당 법정동 삭제
# 사용한 라이브러리
import pandas as pd
from functools import reduce
import numpy as np
# 법정동 테이블
df0 = pd.read_csv('법정동.csv')
df0 = df0[df0['시도명'] == '서울특별시'].drop(['법정동코드', '리명', '순위', '생성일자', '과거법정동코드'], axis = 1)
df0 = df0[df0['삭제일자'].isnull()].reset_index().drop(['삭제일자', 'index', '시도명'], axis=1)
df0 = df0[df0['읍면동명'].notnull()]
법정동 = df0.rename(columns={'시군구명':'CGG_NM', '읍면동명':'STDG_NM'}).reset_index(drop=True)
# 서울시 동별 입시 보습 학원 개수
df1 = pd.read_csv('서울시 학원 교습소 정보.csv', encoding='cp949')
df1 = df1[df1['분야명'] == '입시.검정 및 보습']
df1['CGG_NM'] = df1['도로명주소'].str.extract(r'([가-힣]+구)')
df1['STDG_NM'] = df1['도로명상세주소'].str.extract(r'\(([^,()]+동)')
학원개수 = df1[['CGG_NM', 'STDG_NM']].value_counts().reset_index()
학원개수.columns = ['CGG_NM', 'STDG_NM', 'academy']
# 서울시 동별 유흥주점 개수
df2 = pd.read_csv('서울시 유흥주점영업 인허가 정보.csv', encoding='euc-kr')
df2['CGG_NM'] = df2['지번주소'].str.extract(r'([가-힣]+구)')
df2['STDG_NM'] = df2['지번주소'].str.extract(r'(\S+동)')
유흥주점 = df2[['CGG_NM', 'STDG_NM']].value_counts().reset_index()
유흥주점.columns = ['CGG_NM', 'STDG_NM', 'bar']
# 서울시 동별 병의원 개수
df3 = pd.read_csv('서울시 병의원 위치 정보.csv', encoding='cp949')
df3['CGG_NM'] = df3['주소'].str.extract(r'([가-힣]+구)')
df3['STDG_NM'] = df3['주소'].str.extract(r'\(([^,()]+동)')
병의원수 = df3[['CGG_NM', 'STDG_NM']].value_counts().reset_index()
병의원수.columns = ['CGG_NM', 'STDG_NM', 'hospital']
# 서울시 동별 2차병원
df4 = pd.read_csv('2차병원.csv', encoding='cp949')
df4 = df4[df4['소재지주소'].str.contains('서울특별시')]
df4['CGG_NM'] = df4['소재지주소'].str.extract(r'([가-힣]+구)')
df4['STDG_NM'] = df4['소재지주소'].str.extract(r'\(([^)]+)\)')
병원_2차 = df4[['CGG_NM', 'STDG_NM']].value_counts().reset_index()
병원_2차.columns = ['CGG_NM', 'STDG_NM', 'second_hospital']
# 서울시 동별 3차병원
df5 = pd.read_csv('3차병원.csv',encoding='cp949')
df5 = df5[df5['소재지주소'].str.contains('서울특별시')]
df5['CGG_NM'] = df5['소재지주소'].str.extract(r'([가-힣]+구)')
df5['STDG_NM'] = df5['소재지주소'].str.extract(r'\(([^)]+)\)')
병원_3차 = df5[['CGG_NM', 'STDG_NM']].value_counts().reset_index()
병원_3차.columns = ['CGG_NM', 'STDG_NM', 'third_hospital']
# 대규모점포 테이블 불러오기
df6 = pd.read_csv('서울시 대규모점포 인허가 정보.csv', encoding='euc-kr')
df6 = df6[df6['상세영업상태명'] == '정상영업']
df6['CGG_NM'] = df6['도로명주소'].str.extract(r'([가-힣]+구)')
df6['STDG_NM'] = df6['도로명주소'].str.extract(r'\(([^,()]+동)')
대규모점포 = df6[['CGG_NM', 'STDG_NM']].value_counts().reset_index()
대규모점포.columns = ['CGG_NM', 'STDG_NM', 'store']
# 외부 자료끼리 병합
merge_data = reduce(lambda x,y: pd.merge(x,y, on=['CGG_NM', 'STDG_NM'], how='left'), [법정동, 학원개수, 유흥주점, 대규모점포, 병의원수, 병원_2차, 병원_3차])
merge_data = merge_data.dropna(how='all', subset=['academy', 'bar', 'store', 'hospital', 'second_hospital', 'third_hospital']).reset_index(drop=True)

# %%
# 2. 추천 법정동 찾기(Top N개 법정동 추출)
## 엔트로피 가중치를 이용한 상위 N개 법정동 추출
# 병원 가중치
merge_data['w_second'] = merge_data['second_hospital'] * 5
merge_data['w_third'] = merge_data['third_hospital'] * 20
merge_data = merge_data.fillna(0)
merge_data['t_hospital'] = merge_data['hospital'] + merge_data['w_second'] + merge_data['w_third']
# 엔트로피 지수 구할 지표 추출
data = merge_data[['academy', 'bar', 'store', 't_hospital']]
# 엔트로피 가중치
# 1. 정규화(MIN_MAX)
norm = (data - data.min()) / (data.max() - data.min())
# 2. 엔트로피값
k = 1/np.log(len(data))
entropy = []
for col in norm.columns:
    p = norm[col]/norm[col].sum()
    p = p[p > 0]
    answer = np.sum(p * np.log(p))
    entropy.append(-k * answer)
# 3. 다양성
d = [1-i for i in entropy]
# 4.가중치
w = [i/sum(d) for i in d]
# 가중치 곱한 최종 점수 상위 5개 법정동
top10 = merge_data[['CGG_NM', 'STDG_NM']].copy()
top10['score'] = w[0] * norm['academy'] - w[1] * norm['bar'] + w[2] * norm['store'] + w[3] * norm['t_hospital']
top10 = top10.sort_values('score', ascending=False).head(10)
top10
# Out:
#     CGG_NM STDG_NM     score
# 273    강남구     대치동  0.378522
# 213    양천구      목동  0.308932
# 212    양천구     신정동  0.238327
# 81      중구     신당동  0.227167
# 274    강남구     신사동  0.226731
# 226    구로구     구로동  0.194614
# 160    노원구     상계동  0.181432
# 161    노원구     중계동  0.177573
# 149    강북구     미아동  0.164938
# 118    광진구     구의동  0.161837

# %%
top10.reset_index(drop=True, inplace=True)
top10.index = range(1, len(top10) + 1)
top10
# Out:
#    CGG_NM STDG_NM     score
# 1     강남구     대치동  0.378522
# 2     양천구      목동  0.308932
# 3     양천구     신정동  0.238327
# 4      중구     신당동  0.227167
# 5     강남구     신사동  0.226731
# 6     구로구     구로동  0.194614
# 7     노원구     상계동  0.181432
# 8     노원구     중계동  0.177573
# 9     강북구     미아동  0.164938
# 10    광진구     구의동  0.161837

# %%
# idx = [i for i in range(1, 5)]
# plt.figure(figsize = (10, 5))
# plt.boxplot([data['academy'], data['bar'], data['store'], data['t_hospital']])
# labels = ['academy', 'bar', 'store', 't_hospital']
# plt.xticks(idx, labels)
# plt.show()

# %%
filtered_real_estate = pd.merge(df_final, top10, how='inner', on=['CGG_NM', 'STDG_NM'])
filtered_real_estate
# Out:
#    CGG_NM STDG_NM   MNO SNO         BLDG_NM  ARCH_AREA ARCH_YR     THING_AMT  \
# 0     노원구     중계동    68   1            한신월드      84.38    2005  27100.000000
# 1     양천구      목동   315   6             힐타운      74.05    2004  35000.000000
# 2     노원구     상계동  1320             미라보(성림)      84.50    2006  36400.000000
# 3     구로구     구로동   730   2    남촌홈타운(730-2)      72.26    2004  34000.000000
# 4     양천구     신정동   917  10              장미      70.91    1996  35800.000000
# 5     노원구     상계동   996  16              삼성      81.16    2003  37000.000000
# 6     구로구     구로동   415  37  한일퍼스트빌(415-37)      84.59    2004  38300.000000
# 7     구로구     구로동   415  37  한일퍼스트빌(415-37)      83.18    2004  34770.995998
# 8     노원구     상계동  1049  43              청솔      70.98    2003  39612.540050
# 9     강북구     미아동   224  40              인성      84.84    2004  23882.342986
# 10    노원구     상계동  1117  12          D.S아파트      70.36    2007  29508.471863
# 11    구로구     구로동   415  37  한일퍼스트빌(415-37)      80.16    2004  32723.402650
# 12    광진구     구의동    29   1           성원쌍떼빌      80.84    2003  36742.066133
# 13    노원구     상계동   407   7          충효파크타운      79.98    2006  35593.876566
# 14    강북구     미아동   137  17           한솔드림빌      74.46    2002  34445.687000
# 15    구로구     구로동   739  19        (739-19)      73.26    1995  19519.222633
# 16    구로구     구로동   807  26        (807-26)      70.16    1996  28187.968537
# 17    양천구     신정동   893   6             헤브론      79.49    2003  39463.155952
# 18    노원구     중계동    68   1            한신월드      84.38    2005  37391.340265
# 19    노원구     상계동  1049  43              청솔      70.98    2003  37208.118469
# 20    강북구     미아동   135  44              태솔      72.16    2004  26073.870897
# 21    구로구     구로동   749  96        (749-96)      81.90    1995  33402.742717
# 22    노원구     상계동  1049  43              청솔      83.83    2003  36221.539570
# 23    노원구     중계동    68   1            한신월드      84.38    2005  37482.259324
# 24    노원구     상계동  1049  43              청솔      71.86    2003  32148.245498
# 25    노원구     상계동  1101   2          송이월드A동      78.37    2004  38203.072004
# 26    양천구     신정동  1210   1              자성      81.24    2004  31715.757890
# 27    구로구     구로동   807  26        (807-26)      70.16    1996  28111.694493
# 28    양천구     신정동   918   1           삼백훼미리      78.84    2002  39212.209755
# 29    광진구     구의동    47  23              해성      77.70    2002  36040.633966
# 30    구로구     구로동   770  23        (770-23)      74.06    1995  33566.100823
#
#    FLR BLDG_USG                address 방개수 신축여부     score
# 0    3      아파트     서울특별시 노원구 중계동 68-1  3개   구축  0.177573
# 1    5      아파트     서울특별시 양천구 목동 315-6  3개   구축  0.308932
# 2    2      아파트     서울특별시 노원구 상계동 1320  3개   구축  0.181432
# 3    3      아파트    서울특별시 구로구 구로동 730-2  3개   구축  0.194614
# 4    4      아파트   서울특별시 양천구 신정동 917-10  3개   구축  0.238327
# 5    2      아파트   서울특별시 노원구 상계동 996-16  3개   구축  0.181432
# 6    5      아파트   서울특별시 구로구 구로동 415-37  3개   구축  0.194614
# 7    3      아파트   서울특별시 구로구 구로동 415-37  3개   구축  0.194614
# 8    2      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 9    3      아파트   서울특별시 강북구 미아동 224-40  3개   구축  0.164938
# 10   3      아파트  서울특별시 노원구 상계동 1117-12  3개   구축  0.181432
# 11   7      아파트   서울특별시 구로구 구로동 415-37  3개   구축  0.194614
# 12   4      아파트     서울특별시 광진구 구의동 29-1  3개   구축  0.161837
# 13   3      아파트    서울특별시 노원구 상계동 407-7  3개   구축  0.181432
# 14   4      아파트   서울특별시 강북구 미아동 137-17  3개   구축  0.164938
# 15   3      아파트   서울특별시 구로구 구로동 739-19  3개   구축  0.194614
# 16   5      아파트   서울특별시 구로구 구로동 807-26  3개   구축  0.194614
# 17   2      아파트    서울특별시 양천구 신정동 893-6  3개   구축  0.238327
# 18   3      아파트     서울특별시 노원구 중계동 68-1  3개   구축  0.177573
# 19   4      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 20   6      아파트   서울특별시 강북구 미아동 135-44  3개   구축  0.164938
# 21   3      아파트   서울특별시 구로구 구로동 749-96  3개   구축  0.194614
# 22   6      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 23   3      아파트     서울특별시 노원구 중계동 68-1  3개   구축  0.177573
# 24   6      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 25   4      아파트   서울특별시 노원구 상계동 1101-2  3개   구축  0.181432
# 26   1      아파트   서울특별시 양천구 신정동 1210-1  3개   구축  0.238327
# 27   5      아파트   서울특별시 구로구 구로동 807-26  3개   구축  0.194614
# 28   1      아파트    서울특별시 양천구 신정동 918-1  3개   구축  0.238327
# 29   3      아파트    서울특별시 광진구 구의동 47-23  3개   구축  0.161837
# 30   1      아파트   서울특별시 구로구 구로동 770-23  3개   구축  0.194614

# %%
filtered_real_estate.reset_index(drop=True, inplace=True)
filtered_real_estate.index = range(1, len(filtered_real_estate) + 1)

head = filtered_real_estate.head(3)
tail = filtered_real_estate.tail(3)

ellipsis = pd.DataFrame([['...'] * filtered_real_estate.shape[1]], columns=filtered_real_estate.columns)
ellipsis.index = ['...']  

preview = pd.concat([head, ellipsis, tail])
preview
# Out:
#     CGG_NM STDG_NM   MNO  SNO   BLDG_NM ARCH_AREA ARCH_YR     THING_AMT  FLR  \
# 1      노원구     중계동    68    1      한신월드     84.38    2005       27100.0    3
# 2      양천구      목동   315    6       힐타운     74.05    2004       35000.0    5
# 3      노원구     상계동  1320        미라보(성림)      84.5    2006       36400.0    2
# ...    ...     ...   ...  ...       ...       ...     ...           ...  ...
# 29     양천구     신정동   918    1     삼백훼미리     78.84    2002  39212.209755    1
# 30     광진구     구의동    47   23        해성      77.7    2002  36040.633966    3
# 31     구로구     구로동   770   23  (770-23)     74.06    1995  33566.100823    1
#
#     BLDG_USG               address  방개수 신축여부     score
# 1        아파트    서울특별시 노원구 중계동 68-1   3개   구축  0.177573
# 2        아파트    서울특별시 양천구 목동 315-6   3개   구축  0.308932
# 3        아파트    서울특별시 노원구 상계동 1320   3개   구축  0.181432
# ...      ...                   ...  ...  ...       ...
# 29       아파트   서울특별시 양천구 신정동 918-1   3개   구축  0.238327
# 30       아파트   서울특별시 광진구 구의동 47-23   3개   구축  0.161837
# 31       아파트  서울특별시 구로구 구로동 770-23   3개   구축  0.194614

# %%
# 3. 위치 데이터 이용_경로 계산
## 지하철역 위치 데이터 불러오기
df_sub_addr = pd.read_excel('전체_도시철도역사정보_20250417.xlsx')
df_sub_addr = df_sub_addr[df_sub_addr['운영기관명'].str.contains('서울')]
df_sub_addr.loc[:, 'CGG_NM'] = df_sub_addr['역사도로명주소'].str.extract(r'([가-힣]+구)')
df_sub_addr.loc[:, 'STDG_NM'] = df_sub_addr['역사도로명주소'].str.extract(r'\(([^,()]+동)')
subway = df_sub_addr[['CGG_NM', 'STDG_NM', '역사명', '역위도', '역경도']]
subway = subway.drop_duplicates(subset='역사명')

filtered_subway = subway[
    (subway['CGG_NM'].isin(filtered_real_estate['CGG_NM'])) &
    (subway['STDG_NM'].isin(filtered_real_estate['STDG_NM']))
]

print(filtered_subway)
# Out:
#     CGG_NM STDG_NM          역사명        역위도         역경도
# 56     노원구     상계동           노원  37.656274  127.063183
# 61     강북구     미아동  미아(서울사이버대학)  37.626435  127.026151
# 62     강북구     미아동        미아사거리  37.613276  127.030083
# 63     노원구     상계동          불암산  37.669560  127.078404
# 66     노원구     상계동           상계  37.660576  127.073199
# 532    광진구     구의동   강변(동서울터미널)  37.535161  127.094684
# 535    구로구     구로동      구로디지털단지  37.485005  126.902626
# 536    광진구     구의동     구의(광진구청)  37.536857  127.085024
# 539    구로구     구로동     대림(구로구청)  37.492426  126.895293
# 596    양천구      목동           목동  37.526088  126.864296
# 606    양천구     신정동      신정(은행정)  37.525001  126.856176
# 615    양천구      목동  오목교(목동운동장앞)  37.524557  126.875049
# 676    구로구     구로동          남구로  37.486181  126.887372
# 683    노원구     상계동           마들  37.664985  127.057701
# 691    노원구     상계동          수락산  37.677804  127.055314
# 701    노원구     중계동           중계  37.645052  127.064084
# 784    양천구     신정동        신정네거리  37.520218  126.852849
# 785    양천구     신정동         양천구청  37.512194  126.865193

# %%
## 학교 위치 데이터 불러오기
df_school_addr = pd.read_csv('전국초중등학교위치표준데이터.csv', encoding='cp949')
df_school_addr = df_school_addr[df_school_addr['시도교육청명'] == '서울특별시교육청']
df_school_addr.loc[:, 'CGG_NM'] = df_school_addr['소재지지번주소'].str.extract(r'([가-힣]+구)')
df_school_addr.loc[:, 'STDG_NM'] = df_school_addr['소재지지번주소'].str.extract(r'([가-힣]+동)')
school = df_school_addr[['CGG_NM', 'STDG_NM', '학교명', '위도', '경도']]

filtered_school = school[
    (school['CGG_NM'].isin(filtered_real_estate['CGG_NM'])) &
    (school['STDG_NM'].isin(filtered_real_estate['STDG_NM']))
]
print(filtered_school)
# Out:
#       CGG_NM STDG_NM       학교명         위도          경도
# 438      노원구     중계동  대진여자고등학교  37.646174  127.067197
# 525      구로구     구로동     영림중학교  37.497220  126.890689
# 577      노원구     상계동  서울당현초등학교  37.648260  127.058214
# 624      노원구     중계동  서울청계초등학교  37.645034  127.066139
# 663      양천구      목동  서울경인초등학교  37.532871  126.885696
# ...      ...     ...       ...        ...         ...
# 11680    강북구     미아동  서울삼양초등학교  37.623296  127.016149
# 11767    강북구     미아동  서울미양초등학교  37.621532  127.014133
# 11789    양천구      목동     월촌중학교  37.537065  126.882759
# 11888    노원구     중계동    상명고등학교  37.649548  127.068042
# 11912    노원구     중계동  서울중원초등학교  37.643982  127.062783
#
# [139 rows x 5 columns]

# %%
import pandas as pd
import requests
import time
# ① 카카오 REST API 키 입력
KAKAO_REST_API_KEY = "58a94e08cd433f0a789ddee57624f990"
# ② 주소 → 위도/경도 함수
def get_coords_from_address(address, api_key):
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    headers = {"Authorization": f"KakaoAK {api_key}"}
    params = {"query": address}
    try:
        res = requests.get(url, headers=headers, params=params)
        if res.status_code == 200:
            data = res.json()
            if data['documents']:
                first = data['documents'][0]
                lat = float(first['y'])  # 위도
                lng = float(first['x'])  # 경도
                return lat, lng
    except:
        pass
    return None, None  # 실패 시
# ③ CSV 파일 불러오기
 # 주소 컬럼 이름이 'address'이어야 함
# ④ 위도/경도 리스트 생성
lat_list = []
lng_list = []
# ⑤ 각 행의 address로 좌표 요청
for addr in filtered_real_estate['address']:
    lat, lng = get_coords_from_address(addr, KAKAO_REST_API_KEY)
    lat_list.append(lat)
    lng_list.append(lng)
# ⑥ 좌표 컬럼 추가
filtered_real_estate['위도'] = lat_list
filtered_real_estate['경도'] = lng_list


filtered_real_estate['BLDG_NM'].value_counts()
# Out:
# BLDG_NM
# 청솔                4
# 한신월드              3
# 한일퍼스트빌(415-37)    3
# (807-26)          2
# (739-19)          1
# 해성                1
# 삼백훼미리             1
# 자성                1
# 송이월드A동            1
# (749-96)          1
# 태솔                1
# 헤브론               1
# 충효파크타운            1
# 한솔드림빌             1
# 힐타운               1
# 성원쌍떼빌             1
# D.S아파트            1
# 인성                1
# 삼성                1
# 장미                1
# 남촌홈타운(730-2)      1
# 미라보(성림)           1
# (770-23)          1
# Name: count, dtype: Int64

# %%
# SHP 파일로 변환
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt


geometry = [Point(xy) for xy in zip(filtered_real_estate['경도'], filtered_real_estate['위도'])]
gdf_points = gpd.GeoDataFrame(filtered_real_estate, geometry=geometry, crs="EPSG:4326")
gdf_points = gdf_points.to_crs(epsg=5179)
gdf_points.to_file("real_estate_points_5179.shp", encoding="euc-kr")
gdf_estate = gpd.read_file("real_estate_points_5179.shp")

geometry1 = [Point(xy) for xy in zip(subway["역경도"], subway["역위도"])]
gdf_points1 = gpd.GeoDataFrame(subway, geometry=geometry1, crs="EPSG:4326")
gdf_points1 = gdf_points1.to_crs(epsg=5179)
gdf_points1.to_file("seoul_sub_points_5179.shp", encoding="euc-kr")
gdf_subway = gpd.read_file("seoul_sub_points_5179.shp")

geometry2 = [Point(xy) for xy in zip(school["경도"], school["위도"])]
gdf_points2 = gpd.GeoDataFrame(school, geometry=geometry2, crs="EPSG:4326")
gdf_points2 = gdf_points2.to_crs(epsg=5179)
gdf_points2.to_file("seoul_school_points_5179.shp", encoding="euc-kr")
gdf_school = gpd.read_file("seoul_school_points_5179.shp")


gdf_boundary = gpd.read_file("seoul_emd.shp", encoding='euc-kr')
gdf_boundary = gdf_boundary.to_crs(epsg=5179)

fig, ax = plt.subplots(figsize=(20, 20))
gdf_boundary.plot(ax=ax, edgecolor='gray', facecolor='none', linewidth=0.5)
gdf_subway.plot(ax=ax, color='red', markersize=20)
gdf_school.plot(ax=ax, color='green', markersize=20)
gdf_estate.plot(ax=ax, color='blue', markersize=40)
ax.set_title("Seoul Subway", fontsize=14)
plt.show()
# Out:
# /Users/t2023-m0051/.pyenv/versions/3.12.3/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: One or several characters couldn't be converted correctly from UTF-8 to EUC-KR.  This warning will not be emitted anymore
#   ogr_write(

# %%
import requests
import folium
import pandas as pd
import geopandas as gpd

# Mapbox API 키
MAPBOX_TOKEN = 'pk.eyJ1IjoidmxmdG1kNjAwOCIsImEiOiJjbWMxaTRkOGswNmQ5Mmtvano2MmdqdHdrIn0.ckEJMKAK1p8t7Ss3XfFsFg'

# 지하철 데이터 로드 및 좌표 변환
gdf_subway = gpd.read_file("seoul_sub_points_5179.shp").to_crs(epsg=4326)
subway_info = list(zip(gdf_subway.geometry.x, gdf_subway.geometry.y, gdf_subway['역사명']))

# 학교 데이터 로드 및 좌표 변환
gdf_school = gpd.read_file("seoul_school_points_5179.shp").to_crs(epsg=4326)
school_info = list(zip(gdf_school.geometry.x, gdf_school.geometry.y, gdf_school['학교명']))

# 결과 리스트 초기화
valid_subway_pairs = []
valid_school_pairs = []

# 지도 초기화 (서울 중심)
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)

for idx, row in filtered_real_estate.iterrows():
    dest_lat = row['위도']
    dest_lon = row['경도']
    address = row['address']
    if dest_lat == 0.0 or dest_lon == 0.0:
        continue

    # --- 지하철 처리 ---
    closest_subway = min(subway_info, key=lambda x: (dest_lat - x[1])**2 + (dest_lon - x[0])**2)
    subway_lon, subway_lat, subway_name = closest_subway
    origin_subway = f"{subway_lon},{subway_lat}"
    destination = f"{dest_lon},{dest_lat}"
    url = f"https://api.mapbox.com/directions/v5/mapbox/walking/{origin_subway};{destination}"
    params = {
        "access_token": MAPBOX_TOKEN,
        "geometries": "geojson",
        "overview": "full"
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        if 'routes' in data and data['routes']:
            distance = data['routes'][0]['distance']  # meters
            if distance <= 800:
                valid_subway_pairs.append({
                    '매물주소': address,
                    '지하철역': subway_name,
                    '도보거리(m)': round(distance)
                })
                # 지도에 경로, 마커 추가
                coords = data['routes'][0]['geometry']['coordinates']
                folium.PolyLine(
                    locations=[[lat, lon] for lon, lat in coords],
                    color="blue", weight=3, opacity=0.7
                ).add_to(m)
                folium.Marker(
                    [dest_lat, dest_lon],
                    popup=f"매물\n{address}",
                    icon=folium.Icon(color="red", icon="home")
                ).add_to(m)
                folium.Marker(
                    [subway_lat, subway_lon],
                    popup=f"지하철: {subway_name}",
                    icon=folium.Icon(color="green", icon="train")
                ).add_to(m)
    except Exception as e:
        print(f"지하철 경로 오류: {origin_subway} → {destination} / {e}")

    # --- 학교 처리 ---
    closest_school = min(school_info, key=lambda x: (dest_lat - x[1])**2 + (dest_lon - x[0])**2)
    school_lon, school_lat, school_name = closest_school
    origin_school = f"{school_lon},{school_lat}"
    try:
        response = requests.get(f"https://api.mapbox.com/directions/v5/mapbox/walking/{origin_school};{destination}", params=params)
        data = response.json()
        if 'routes' in data and data['routes']:
            distance = data['routes'][0]['distance']
            if distance <= 800:
                valid_school_pairs.append({
                    '매물주소': address,
                    '학교': school_name,
                    '도보거리(m)': round(distance)
                })
                # 지도에 경로, 마커 추가
                coords = data['routes'][0]['geometry']['coordinates']
                folium.PolyLine(
                    locations=[[lat, lon] for lon, lat in coords],
                    color="purple", weight=3, opacity=0.7
                ).add_to(m)
                folium.Marker(
                    [dest_lat, dest_lon],
                    popup=f"매물\n{address}",
                    icon=folium.Icon(color="red", icon="home")
                ).add_to(m)
                folium.Marker(
                    [school_lat, school_lon],
                    popup=f"학교: {school_name}",
                    icon=folium.Icon(color="darkgreen", icon="school")
                ).add_to(m)
    except Exception as e:
        print(f"학교 경로 오류: {origin_school} → {destination} / {e}")

# 데이터프레임으로 변환 후 출력
df_subway = pd.DataFrame(valid_subway_pairs)
df_school = pd.DataFrame(valid_school_pairs)

display(df_subway)
display(df_school)

# 지도 저장
m.save("mapbox_routes_all.html")
m
# Out:
#                      매물주소           지하철역  도보거리(m)
# 0      서울특별시 노원구 상계동 1320            불암산      438
# 1     서울특별시 구로구 구로동 730-2            남구로      601
# 2    서울특별시 양천구 신정동 917-10        신정(은행정)       64
# 3    서울특별시 노원구 상계동 996-16            수락산      576
# 4   서울특별시 노원구 상계동 1049-43            수락산      567
# 5    서울특별시 강북구 미아동 224-40    미아(서울사이버대학)      223
# 6   서울특별시 노원구 상계동 1117-12            수락산      218
# 7      서울특별시 광진구 구의동 29-1  아차산(어린이대공원후문)      390
# 8     서울특별시 노원구 상계동 407-7             노원      712
# 9    서울특별시 강북구 미아동 137-17          미아사거리      701
# 10   서울특별시 구로구 구로동 739-19            남구로      482
# 11   서울특별시 구로구 구로동 807-26            남구로      235
# 12    서울특별시 양천구 신정동 893-6             목동      545
# 13  서울특별시 노원구 상계동 1049-43            수락산      567
# 14   서울특별시 구로구 구로동 749-96            남구로      357
# 15  서울특별시 노원구 상계동 1049-43            수락산      567
# 16  서울특별시 노원구 상계동 1049-43            수락산      567
# 17   서울특별시 노원구 상계동 1101-2            수락산      505
# 18   서울특별시 양천구 신정동 1210-1          신정네거리      532
# 19   서울특별시 구로구 구로동 807-26            남구로      235
# 20    서울특별시 양천구 신정동 918-1        신정(은행정)      223
# 21    서울특별시 광진구 구의동 47-23  아차산(어린이대공원후문)      348
# 22   서울특별시 구로구 구로동 770-23            남구로      269
#                      매물주소         학교  도보거리(m)
# 0      서울특별시 노원구 중계동 68-1   서울수암초등학교      239
# 1      서울특별시 양천구 목동 315-6   서울양화초등학교      686
# 2     서울특별시 구로구 구로동 730-2      구로중학교      727
# 3    서울특별시 양천구 신정동 917-10     신서고등학교      613
# 4    서울특별시 노원구 상계동 996-16   서울노원초등학교       89
# 5   서울특별시 노원구 상계동 1049-43      노일중학교      510
# 6   서울특별시 노원구 상계동 1117-12   서울노일초등학교      447
# 7      서울특별시 광진구 구의동 29-1   선화예술고등학교      653
# 8     서울특별시 노원구 상계동 407-7   서울상계초등학교      125
# 9    서울특별시 강북구 미아동 137-17   서울송중초등학교      271
# 10   서울특별시 구로구 구로동 739-19   서울영일초등학교      439
# 11   서울특별시 구로구 구로동 807-26   서울영일초등학교      300
# 12    서울특별시 양천구 신정동 893-6   서울양목초등학교      607
# 13     서울특별시 노원구 중계동 68-1   서울수암초등학교      239
# 14  서울특별시 노원구 상계동 1049-43      노일중학교      510
# 15   서울특별시 강북구 미아동 135-44   서울화계초등학교      428
# 16   서울특별시 구로구 구로동 749-96   서울영일초등학교      520
# 17  서울특별시 노원구 상계동 1049-43      노일중학교      510
# 18     서울특별시 노원구 중계동 68-1   서울수암초등학교      239
# 19  서울특별시 노원구 상계동 1049-43      노일중학교      510
# 20   서울특별시 노원구 상계동 1101-2   서울노일초등학교      543
# 21   서울특별시 양천구 신정동 1210-1      신남중학교      428
# 22   서울특별시 구로구 구로동 807-26   서울영일초등학교      300
# 23    서울특별시 양천구 신정동 918-1   서울양동초등학교      663
# 24    서울특별시 광진구 구의동 47-23   서울광진초등학교      659
# 25   서울특별시 구로구 구로동 770-23  서울구로남초등학교      586
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4297f2e14f2ee3ea0fb6e7ce8510dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4297f2e14f2ee3ea0fb6e7ce8510dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4297f2e14f2ee3ea0fb6e7ce8510dba = L.map(
#                 &quot;map_a4297f2e14f2ee3ea0fb6e7ce8510dba&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e1afef8925f3e26e88b2f443f65d1eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e1afef8925f3e26e88b2f443f65d1eb.addTo(map_a4297f2e14f2ee3ea0fb6e7ce8510dba);
#
#
#             var poly_line_a400df9a7c0bcb7bc20fde6c258abb02 = L.polyline(
#                 [[37.647637, 127.081383], [37.64728, 127.081775], [37.647777, 127.082521], [37.648071, 127.082957], [37.648095, 127.082993], [37.648163, 127.083138], [37.648167, 127.083191], [37.648364, 127.083361]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4297f2e14f2ee3ea0fb6e7ce8510dba);
#
#
#             var marker_f4535de6bb90276e7a894f83bd93497a = L.marker(
#                 [37.6484835223053, 127.083663400175],
#                 {
# }
#             ).addTo(map_a4297f2e14f2ee3ea0fb6e7ce8510dba);
#
#
#             var icon_ca8068c3562204fe290abffb4644a8a9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8deca35c020eb821aef55260f0896a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_338717a42abc99cc6f58616bc80bd2cf = $(`&lt;div id=&quot;html_338717a42abc99cc6f58616bc80bd2cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;매물 서울특별시 노원구 중계동 68-1&lt;/div&gt;`)[0];
#                 popup_8deca35c020eb821aef55260f0896a9e.setContent(html_338717a42abc99cc6f58616bc80bd2cf);
#
#
#
#         marker_f4535de6bb90276e7a894f83bd93497a.bindPopup(popup_8deca35c020eb821aef55260f0896a9e)
#         ;
#
#
#
#
#                 marker_f4535de6bb90276e7a894f83bd93497a.setIcon(icon_ca8068c3562204fe290abffb4644a8a9);
#
#
#             var marker_05cfd34600a7c06b967a3c8aeab782e3 = L.marker(
#                 [37.647692830000004, 127.0814646],
#                 {
# }
#             ).addTo(map_a4297f2e14f2ee3ea0fb6e7ce8510dba);
#
#
#             var icon_5e1a50f8730ef7025fbff9fd17fb6626 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkgreen&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;school&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_586d6daa886014b854422c2aa61df37b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fffaa2ed5028ae60a6628192552326c = $(`&lt;div id=&quot;html_6fffaa2ed5028ae60a6628192552326c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;학교: 서울수암초등학교&lt;/div&gt;`)[0];
#                 popup_586d6daa886014b854422c2aa61df37b.setContent(html_6fffaa2ed5028ae60a6628192552326c);
#
#
#
#         marker_05cfd34600a7c06b967a3c8aeab782e3.bindPopup(popup_586d6daa886014b854422c2aa61df37b)
#         ;
#
#
#
#
#                 marker_05cfd34600a7c06b967a3c8aeab782e3.setIcon(icon_5e1a50f8730ef7025fbff9fd17fb6626);
#
#
#             var poly_line_977158899ee8c179168f67325a561296 = L.polyline(
#                 [[37.543643, 126.873944], [37.543365, 126.873966], [37.543196, 126.873979], [37.543182, 126.873603], [37.543169, 126.87327], [37.543157, 126.872949], [37.543152, 126.87271], [37.543225, 126.872507], [37.543419, 126.871973], [37.543592, 126.871438], [37.543855, 126.870445], [37.54361, 126.87034], [37.543481, 126.870278], [37.543436, 126

# %%
final_real_estate = pd.merge(df_subway, df_school, how='inner', on=['매물주소'])
final_real_estate
# Out:
#                      매물주소           지하철역  도보거리(m)_x         학교  도보거리(m)_y
# 0     서울특별시 구로구 구로동 730-2            남구로        601      구로중학교        727
# 1    서울특별시 양천구 신정동 917-10        신정(은행정)         64     신서고등학교        613
# 2    서울특별시 노원구 상계동 996-16            수락산        576   서울노원초등학교         89
# 3   서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 4   서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 5   서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 6   서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 7   서울특별시 노원구 상계동 1117-12            수락산        218   서울노일초등학교        447
# 8      서울특별시 광진구 구의동 29-1  아차산(어린이대공원후문)        390   선화예술고등학교        653
# 9     서울특별시 노원구 상계동 407-7             노원        712   서울상계초등학교        125
# 10   서울특별시 강북구 미아동 137-17          미아사거리        701   서울송중초등학교        271
# 11   서울특별시 구로구 구로동 739-19            남구로        482   서울영일초등학교        439
# 12   서울특별시 구로구 구로동 807-26            남구로        235   서울영일초등학교        300
# 13   서울특별시 구로구 구로동 807-26            남구로        235   서울영일초등학교        300
# 14    서울특별시 양천구 신정동 893-6             목동        545   서울양목초등학교        607
# 15  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 16  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 17  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 18  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 19   서울특별시 구로구 구로동 749-96            남구로        357   서울영일초등학교        520
# 20  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 21  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 22  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 23  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 24  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 25  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 26  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 27  서울특별시 노원구 상계동 1049-43            수락산        567      노일중학교        510
# 28   서울특별시 노원구 상계동 1101-2            수락산        505   서울노일초등학교        543
# 29   서울특별시 양천구 신정동 1210-1          신정네거리        532      신남중학교        428
# 30   서울특별시 구로구 구로동 807-26            남구로        235   서울영일초등학교        300
# 31   서울특별시 구로구 구로동 807-26            남구로        235   서울영일초등학교        300
# 32    서울특별시 양천구 신정동 918-1        신정(은행정)        223   서울양동초등학교        663
# 33    서울특별시 광진구 구의동 47-23  아차산(어린이대공원후문)        348   서울광진초등학교        659
# 34   서울특별시 구로구 구로동 770-23            남구로        269  서울구로남초등학교        586

# %%
final_real_estate_df = filtered_real_estate[(filtered_real_estate['address'].isin(final_real_estate['매물주소']))]
final_real_estate_df
# Out:
#    CGG_NM STDG_NM   MNO SNO       BLDG_NM  ARCH_AREA ARCH_YR     THING_AMT  \
# 4     구로구     구로동   730   2  남촌홈타운(730-2)      72.26    2004  34000.000000
# 5     양천구     신정동   917  10            장미      70.91    1996  35800.000000
# 6     노원구     상계동   996  16            삼성      81.16    2003  37000.000000
# 9     노원구     상계동  1049  43            청솔      70.98    2003  39612.540050
# 11    노원구     상계동  1117  12        D.S아파트      70.36    2007  29508.471863
# 13    광진구     구의동    29   1         성원쌍떼빌      80.84    2003  36742.066133
# 14    노원구     상계동   407   7        충효파크타운      79.98    2006  35593.876566
# 15    강북구     미아동   137  17         한솔드림빌      74.46    2002  34445.687000
# 16    구로구     구로동   739  19      (739-19)      73.26    1995  19519.222633
# 17    구로구     구로동   807  26      (807-26)      70.16    1996  28187.968537
# 18    양천구     신정동   893   6           헤브론      79.49    2003  39463.155952
# 20    노원구     상계동  1049  43            청솔      70.98    2003  37208.118469
# 22    구로구     구로동   749  96      (749-96)      81.90    1995  33402.742717
# 23    노원구     상계동  1049  43            청솔      83.83    2003  36221.539570
# 25    노원구     상계동  1049  43            청솔      71.86    2003  32148.245498
# 26    노원구     상계동  1101   2        송이월드A동      78.37    2004  38203.072004
# 27    양천구     신정동  1210   1            자성      81.24    2004  31715.757890
# 28    구로구     구로동   807  26      (807-26)      70.16    1996  28111.694493
# 29    양천구     신정동   918   1         삼백훼미리      78.84    2002  39212.209755
# 30    광진구     구의동    47  23            해성      77.70    2002  36040.633966
# 31    구로구     구로동   770  23      (770-23)      74.06    1995  33566.100823
#
#    FLR BLDG_USG                address 방개수 신축여부     score
# 4    3      아파트    서울특별시 구로구 구로동 730-2  3개   구축  0.194614
# 5    4      아파트   서울특별시 양천구 신정동 917-10  3개   구축  0.238327
# 6    2      아파트   서울특별시 노원구 상계동 996-16  3개   구축  0.181432
# 9    2      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 11   3      아파트  서울특별시 노원구 상계동 1117-12  3개   구축  0.181432
# 13   4      아파트     서울특별시 광진구 구의동 29-1  3개   구축  0.161837
# 14   3      아파트    서울특별시 노원구 상계동 407-7  3개   구축  0.181432
# 15   4      아파트   서울특별시 강북구 미아동 137-17  3개   구축  0.164938
# 16   3      아파트   서울특별시 구로구 구로동 739-19  3개   구축  0.194614
# 17   5      아파트   서울특별시 구로구 구로동 807-26  3개   구축  0.194614
# 18   2      아파트    서울특별시 양천구 신정동 893-6  3개   구축  0.238327
# 20   4      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 22   3      아파트   서울특별시 구로구 구로동 749-96  3개   구축  0.194614
# 23   6      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 25   6      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 26   4      아파트   서울특별시 노원구 상계동 1101-2  3개   구축  0.181432
# 27   1      아파트   서울특별시 양천구 신정동 1210-1  3개   구축  0.238327
# 28   5      아파트   서울특별시 구로구 구로동 807-26  3개   구축  0.194614
# 29   1      아파트    서울특별시 양천구 신정동 918-1  3개   구축  0.238327
# 30   3      아파트    서울특별시 광진구 구의동 47-23  3개   구축  0.161837
# 31   1      아파트   서울특별시 구로구 구로동 770-23  3개   구축  0.194614

# %%
final_real_estate_df = final_real_estate_df.sort_values(by=['THING_AMT','BLDG_NM'], ascending=[False,True]).reset_index(drop=True)
final_real_estate_df
# Out:
#    CGG_NM STDG_NM   MNO SNO       BLDG_NM  ARCH_AREA ARCH_YR     THING_AMT  \
# 0     노원구     상계동  1049  43            청솔      70.98    2003  39612.540050
# 1     양천구     신정동   893   6           헤브론      79.49    2003  39463.155952
# 2     양천구     신정동   918   1         삼백훼미리      78.84    2002  39212.209755
# 3     노원구     상계동  1101   2        송이월드A동      78.37    2004  38203.072004
# 4     노원구     상계동  1049  43            청솔      70.98    2003  37208.118469
# 5     노원구     상계동   996  16            삼성      81.16    2003  37000.000000
# 6     광진구     구의동    29   1         성원쌍떼빌      80.84    2003  36742.066133
# 7     노원구     상계동  1049  43            청솔      83.83    2003  36221.539570
# 8     광진구     구의동    47  23            해성      77.70    2002  36040.633966
# 9     양천구     신정동   917  10            장미      70.91    1996  35800.000000
# 10    노원구     상계동   407   7        충효파크타운      79.98    2006  35593.876566
# 11    강북구     미아동   137  17         한솔드림빌      74.46    2002  34445.687000
# 12    구로구     구로동   730   2  남촌홈타운(730-2)      72.26    2004  34000.000000
# 13    구로구     구로동   770  23      (770-23)      74.06    1995  33566.100823
# 14    구로구     구로동   749  96      (749-96)      81.90    1995  33402.742717
# 15    노원구     상계동  1049  43            청솔      71.86    2003  32148.245498
# 16    양천구     신정동  1210   1            자성      81.24    2004  31715.757890
# 17    노원구     상계동  1117  12        D.S아파트      70.36    2007  29508.471863
# 18    구로구     구로동   807  26      (807-26)      70.16    1996  28187.968537
# 19    구로구     구로동   807  26      (807-26)      70.16    1996  28111.694493
# 20    구로구     구로동   739  19      (739-19)      73.26    1995  19519.222633
#
#    FLR BLDG_USG                address 방개수 신축여부     score
# 0    2      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 1    2      아파트    서울특별시 양천구 신정동 893-6  3개   구축  0.238327
# 2    1      아파트    서울특별시 양천구 신정동 918-1  3개   구축  0.238327
# 3    4      아파트   서울특별시 노원구 상계동 1101-2  3개   구축  0.181432
# 4    4      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 5    2      아파트   서울특별시 노원구 상계동 996-16  3개   구축  0.181432
# 6    4      아파트     서울특별시 광진구 구의동 29-1  3개   구축  0.161837
# 7    6      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 8    3      아파트    서울특별시 광진구 구의동 47-23  3개   구축  0.161837
# 9    4      아파트   서울특별시 양천구 신정동 917-10  3개   구축  0.238327
# 10   3      아파트    서울특별시 노원구 상계동 407-7  3개   구축  0.181432
# 11   4      아파트   서울특별시 강북구 미아동 137-17  3개   구축  0.164938
# 12   3      아파트    서울특별시 구로구 구로동 730-2  3개   구축  0.194614
# 13   1      아파트   서울특별시 구로구 구로동 770-23  3개   구축  0.194614
# 14   3      아파트   서울특별시 구로구 구로동 749-96  3개   구축  0.194614
# 15   6      아파트  서울특별시 노원구 상계동 1049-43  3개   구축  0.181432
# 16   1      아파트   서울특별시 양천구 신정동 1210-1  3개   구축  0.238327
# 17   3      아파트  서울특별시 노원구 상계동 1117-12  3개   구축  0.181432
# 18   5      아파트   서울특별시 구로구 구로동 807-26  3개   구축  0.194614
# 19   5      아파트   서울특별시 구로구 구로동 807-26  3개   구축  0.194614
# 20   3      아파트   서울특별시 구로구 구로동 739-19  3개   구축  0.194614

# %%
print(type(final_real_estate_df))
final_real_estate_df = pd.DataFrame(final_real_estate_df)

final_real_estate_df = final_real_estate_df[['CGG_NM', 'STDG_NM', 'BLDG_NM', 'THING_AMT']]
final_real_estate_df
final_real_estate_df.reset_index(drop=True, inplace=True)
final_real_estate_df.index = range(1, len(final_real_estate_df) + 1)

head2 = final_real_estate_df.head(3)
tail2 = final_real_estate_df.tail(3)


ellipsis2 = pd.DataFrame([['...'] * final_real_estate_df.shape[1]], columns=final_real_estate_df.columns)
ellipsis2.index = ['...']

preview2 = pd.concat([head2, ellipsis2, tail2])
preview2
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     CGG_NM STDG_NM   BLDG_NM     THING_AMT
# 1      노원구     상계동        청솔   39612.54005
# 2      양천구     신정동       헤브론  39463.155952
# 3      양천구     신정동     삼백훼미리  39212.209755
# ...    ...     ...       ...           ...
# 19     구로구     구로동  (807-26)  28187.968537
# 20     구로구     구로동  (807-26)  28111.694493
# 21     구로구     구로동  (739-19)  19519.222633
